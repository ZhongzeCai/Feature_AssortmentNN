# %%
from run_experiment import runner
import os

runner('configs/xWy_10_xWyModel.yaml')
# Out:
# train loss
# 	train loss       	 (min:    0.743, max:    3.915, cur:    0.743)
# valid loss
# 	valid loss       	 (min:    0.649, max:    3.832, cur:    0.649)
