# %%
from run_experiment import runner
import os

runner('configs/xWy_10_xWyModel.yaml')
# Out:
# train loss
# 	train loss       	 (min:    0.688, max:    5.126, cur:    0.688)
# valid loss
# 	valid loss       	 (min:    0.687, max:    5.287, cur:    0.687)

# %%
from run_experiment import runner
import os

runner('configs/xWy_10_S03_xWyModel.yaml')
# Out:
# train loss
# 	train loss       	 (min:    1.364, max:    3.576, cur:    1.364)
# valid loss
# 	valid loss       	 (min:    1.343, max:    3.599, cur:    1.344)

# %%
from run_experiment import runner
import os

runner('configs/Markov_10_S01_xWyModel.yaml')
# Out:
# train loss
# 	train loss       	 (min:    1.757, max:    3.128, cur:    1.757)
# valid loss
# 	valid loss       	 (min:    1.783, max:    2.984, cur:    1.783)

# %%
from run_experiment import runner
import os

runner('configs/Markov_10_xWyModel.yaml')
# Out:
# train loss
# 	train loss       	 (min:    1.657, max:    2.755, cur:    1.657)
# valid loss
# 	valid loss       	 (min:    1.776, max:    2.762, cur:    1.776)

# %%
from run_experiment import runner
import os

runner('configs/Markov_10_UtilsModel.yaml')
# Out:
# train loss
# 	train loss       	 (min:    1.395, max:    1.940, cur:    1.412)
# valid loss
# 	valid loss       	 (min:    1.443, max:    1.833, cur:    1.455)

# %%
from run_experiment import runner
import os

runner('configs/Markov_10_UtilsModel_2Layers.yaml')
# Out:
# train loss
# 	train loss       	 (min:    1.244, max:    1.844, cur:    1.247)
# valid loss
# 	valid loss       	 (min:    1.296, max:    1.709, cur:    1.297)
